# %%
import pandas as pd

# %%
df = pd.read_csv("NYC_taxi_with_coordinates_weather.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2942063 entries, 0 to 2942062
# Data columns (total 36 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0.1           int64
#  1   Unnamed: 0             int64
#  2   index                  int64
#  3   VendorID               int64
#  4   tpep_pickup_datetime   object
#  5   tpep_dropoff_datetime  object
#  6   passenger_count        float64
#  7   trip_distance          float64
#  8   RatecodeID             float64
#  9   store_and_fwd_flag     object
#  10  PULocationID           int64
#  11  DOLocationID           int64
#  12  payment_type           int64
#  13  fare_amount            float64
#  14  extra                  float64
#  15  mta_tax                float64
#  16  tip_amount             float64
#  17  tolls_amount           float64
#  18  improvement_surcharge  float64
#  19  total_amount           float64
#  20  congestion_surcharge   float64
# ...

# %%
df
# Out:
#          Unnamed: 0.1  Unnamed: 0    index  VendorID tpep_pickup_datetime  \
# 0                   0           0  1850612         2  2023-10-01 00:00:00
# 1                   1           1  1899716         2  2023-10-01 00:00:00
# 2                   2           2  1615889         1  2023-10-01 00:00:01
# 3                   3           3  1602363         2  2023-10-01 00:00:01
# 4                   4           4  2110464         2  2023-10-01 00:00:02
# ...               ...         ...      ...       ...                  ...
# 2942058       2942058     2942058  1617060         2  2023-10-27 13:28:03
# 2942059       2942059     2942059   378381         1  2023-10-27 13:28:04
# 2942060       2942060     2942060  1451223         2  2023-10-27 13:28:04
# 2942061       2942061     2942061  1766881         1  2023-10-27 13:28:04
# 2942062       2942062     2942062  1749528         2  2023-10-27 13:28:04
#
#         tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
print(pp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(pp)
#
# NameError: name 'pp' is not defined

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2942063 entries, 0 to 2942062
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0.1           2942063 non-null  int64
#  1   Unnamed: 0             2942063 non-null  int64
#  2   index                  2942063 non-null  int64
#  3   VendorID               2942063 non-null  int64
#  4   tpep_pickup_datetime   2942063 non-null  object
#  5   tpep_dropoff_datetime  2942063 non-null  object
#  6   passenger_count        2817012 non-null  float64
#  7   trip_distance          2942063 non-null  float64
#  8   RatecodeID             2817012 non-null  float64
#  9   store_and_fwd_flag     2817012 non-null  object
#  10  PULocationID           2942063 non-null  int64
#  11  DOLocationID           2942063 non-null  int64
#  12  payment_type           2942063 non-null  int64
#  13  fare_amount            2942063 non-null  float64
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2942063 entries, 0 to 2942062
# Data columns (total 36 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0.1           int64
#  1   Unnamed: 0             int64
#  2   index                  int64
#  3   VendorID               int64
#  4   tpep_pickup_datetime   object
#  5   tpep_dropoff_datetime  object
#  6   passenger_count        float64
#  7   trip_distance          float64
#  8   RatecodeID             float64
#  9   store_and_fwd_flag     object
#  10  PULocationID           int64
#  11  DOLocationID           int64
#  12  payment_type           int64
#  13  fare_amount            float64
#  14  extra                  float64
#  15  mta_tax                float64
#  16  tip_amount             float64
#  17  tolls_amount           float64
#  18  improvement_surcharge  float64
#  19  total_amount           float64
#  20  congestion_surcharge   float64
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2942063 entries, 0 to 2942062
# Data columns (total 36 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0.1           int64
#  1   Unnamed: 0             int64
#  2   index                  int64
#  3   VendorID               int64
#  4   tpep_pickup_datetime   object
#  5   tpep_dropoff_datetime  object
#  6   passenger_count        float64
#  7   trip_distance          float64
#  8   RatecodeID             float64
#  9   store_and_fwd_flag     object
#  10  PULocationID           int64
#  11  DOLocationID           int64
#  12  payment_type           int64
#  13  fare_amount            float64
#  14  extra                  float64
#  15  mta_tax                float64
#  16  tip_amount             float64
#  17  tolls_amount           float64
#  18  improvement_surcharge  float64
#  19  total_amount           float64
#  20  congestion_surcharge   float64
# ...

# %%
summary = pd.DataFrame({
    'dtype': df.dtypes,
    'non_null_count': df.count(),
    'null_count': df.isnull().sum(),
    'null_percent': (df.isnull().mean() * 100).round(2)
})

summary = summary.sort_values('null_percent', ascending=False)
print(summary)
# Out:
#                          dtype  non_null_count  null_count  null_percent
# congestion_surcharge   float64         2817012      125051          4.25
# store_and_fwd_flag      object         2817012      125051          4.25
# RatecodeID             float64         2817012      125051          4.25
# passenger_count        float64         2817012      125051          4.25
# airport_fee            float64         2817012      125051          4.25
# Dlatitude              float64         2904139       37924          1.29
# Dlongitude             float64         2904139       37924          1.29
# Platitude              float64         2919885       22178          0.75
# Plongitude             float64         2919885       22178          0.75
# index                    int64         2942063           0          0.00
# Unnamed: 0               int64         2942063           0          0.00
# Unnamed: 0.1             int64         2942063           0          0.00
# ...

# %%
df['PULocationID'].value_counts().reset_index(name='count').rename(columns={'index': 'PULocationID'})
# Out:
#      PULocationID   count
# 0             132  150198
# 1             237  141767
# 2             161  140998
# 3             236  126997
# 4             138  104486
# ..            ...     ...
# 246           251       1
# 247            84       1
# 248           118       1
# 249           105       1
# 250           187       1
#
# [251 rows x 2 columns]

# %%
df.dtypes.to_csv("columns_dtypes.csv")

# %%
df[(df["payment_type"]== 0 )]
# Out:
#          Unnamed: 0.1  Unnamed: 0    index  VendorID tpep_pickup_datetime  \
# 22                 22          22   847982         1  2023-10-01 00:00:09
# 25                 25          25   111719         2  2023-10-01 00:00:12
# 57                 57          57   315516         1  2023-10-01 00:00:30
# 110               110         110   559944         1  2023-10-01 00:01:07
# 125               125         125  1076620         1  2023-10-01 00:01:14
# ...               ...         ...      ...       ...                  ...
# 2941904       2941904     2941904  1820352         1  2023-10-27 13:26:28
# 2942015       2942015     2942015  1359980         2  2023-10-27 13:27:40
# 2942041       2942041     2942041   362235         1  2023-10-27 13:27:56
# 2942053       2942053     2942053  2059434         1  2023-10-27 13:28:00
# 2942061       2942061     2942061  1766881         1  2023-10-27 13:28:04
#
#         tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 missing_pickup = df[~df["PULocationID"].isin(dfm["LocationID"])]
#       2 print("Missing pickup location IDs:", missing_pickup["PULocationID"].nunique())
#
# NameError: name 'dfm' is not defined
